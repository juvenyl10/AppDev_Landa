# %% [markdown]
# # **CHAPTER 1 - Introduction**

# %% [markdown]
# # **Exercise 1:**

# %%
Print('Hello world!')
#The error is the "Print" function, Python is a case sensitive programming language.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-396c6e7ba2f7> in <cell line: 1>()
# ----> 1 Print('Hello world!')
#       2 #The error is the "Print" function, Python is a case sensitive programming language.
#
# NameError: name 'Print' is not defined

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print'Hello world!')
#The error is the absence of "(" open parenthesis
# Out:
#   File "<ipython-input-4-7392ed0ae854>", line 1
#     print'Hello world!')
#                        ^
# SyntaxError: unmatched ')'

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print('Hello world!)
#The error is the absence of "'" single quote after the "!" exclamation mark, unterminated string literal
# Out:
#   File "<ipython-input-8-ceefb7165fb3>", line 1
#     print('Hello world!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print('Hello world!'')
#The error is the 2 single quote after the "!" exclamation mark. Users should utilize single quote('') or double quote("") in print function, unterminated string literal
# Out:
#   File "<ipython-input-11-ebf1ef196e0f>", line 1
#     print('Hello world!'')
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# # **Exercise 2:**

# %%
x = 43
x = x + 1
print(x)
# variable x is initialized to 43, 43 + 1 = 44
# Out:
# 44

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %% [markdown]
# # **Exercise 3:**

# %%
x = 43
x = X + 1
print(x)
# python is case sensitive, variable "X" is different from "x". Therefore, variable "X" is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4795961764ec> in <cell line: 2>()
#       1 x = 43
# ----> 2 x = X + 1
#       3 print(x)
#       4 # python is case sensitive, variable "X" is different from "x"
#
# NameError: name 'X' is not defined

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44
