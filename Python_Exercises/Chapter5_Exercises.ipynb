# %% [markdown]
# # **CHAPTER 5 - ITERATIONS**

# %% [markdown]
# # **Exercise 1:**

# %% [markdown]
# Investigate on the difference between is and == given the following variables.

# %%
a = 2
b = 2.0
c = a

# %%
a = 2
b = 2.0
c = a

print(a is a)
print(a == a)
print("")

print(a is b)
print(a == b)
print("")

print(a is c)
print(a == c)
print("")

print(b is b)
print(b == b)
print("")

print(b is c)
print(b == c)
print("")

print(c is c)
print(c == c)

#"is" is an operator that identifies the 2 variables, checking whether the variables refer to the same object in memory.
#"==" is an operator that compares the 2 variables, checking whether there is equality on there values.
# Out:
# True
# True
#
# False
# True
#
# True
# True
#
# True
# True
#
# False
# True
#
# True
# True

# %% [markdown]
# # **CHALLENGES**

# %% [markdown]
# # **Challenge 1:**

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.

# %%
total = 0
count = 0

while True:

    num = input('Enter a number: ')
    num = num.lower()
    if num == 'done' :
        break
    try:
      num = int(num)
      total += num
      count = count + 1
    except:
      print('Invalid Input')

    ave = total/count

print(total,count,ave)
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid Input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333

# %% [markdown]
# # **Challenge 2:**

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.

# %%
max = None
min = None

while True:

    num = input('Enter a number: ')
    num = num.lower()
    if num == 'done' :
        break
    try:
      num = int(num)
      if max is None or num > max:
        max = num
      elif min is None or num < min:
        min = num
    except:
      print('Invalid Input')
      continue

if max is None or min is None:
  print('No number is entered')
else:
  print(max,min)
# Out:
# Enter a number: 10
# Enter a number: 8
# Enter a number: jal
# Invalid Input
# Enter a number: 88
# Enter a number: DoNe
# 88 8
